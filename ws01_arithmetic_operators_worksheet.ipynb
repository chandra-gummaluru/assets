# %% [markdown]
# # CSC108H Fall 2026
# # Worksheet 01: Arithmetic Operators
#
# Live-coding notebook. Run each setup cell, then fill in the code cell below it during lecture.

# %% [markdown]
# ## Question 1
#
# A student earns `n` marks and `b` bonus marks on a test out of `total` possible marks. Write a Python expression to produce the student's grade as a percentage between 0 and 100.
#
# For example, if `n` refers to 7, `b` refers to 1, and `total` refers to 10, the expression should produce `80.0`.

# %%
n = 7
b = 1
total = 10

# %% [markdown]
# ## Question 2
#
# A group of friends goes to a restaurant. The total bill costs `total_cost` and it will be split evenly between `n` people.
#
# **(a)** Write a Python expression that produces the amount each person should pay. (It is fine if the amount has more than two digits after the decimal place. You'll learn how to round later.)

# %%
total_cost = 21
n = 4

# %% [markdown]
# **(b)** If `total_cost` refers to 21 and `n` refers to 4, what value does the expression above produce? What type does that value have?
#
# Run the cell above, then check below.

# %%
# check the value and type produced when total_cost = 21 and n = 4

# %% [markdown]
# **(c)** If `total_cost` refers to 20 and `n` refers to 4, what value does the expression above produce? What type does that value have?

# %%
total_cost = 20
n = 4

# check the value and type produced with these new values

# %% [markdown]
# ## Question 3
#
# Your roommate ordered pizzas to be shared among a group of people. They ordered `num_pizzas` pizzas, each containing `num_slices` slices of pizza, and there are `num_people` people.
#
# **(a)** Write a Python assignment statement that assigns the number of whole slices each person gets to a variable named `slices_per_person`.

# %%
num_pizzas = 2
num_slices = 10
num_people = 3

# %% [markdown]
# **(b)** Create a variable named `leftover` that refers to the number of slices left over.

# %% [markdown]
# **(c)** If `num_pizzas` refers to 2, `num_slices` refers to 10, and `num_people` refers to 3, what values do the variables `slices_per_person` and `leftover` refer to? What types do those values have?

# %%
print(slices_per_person, type(slices_per_person))
print(leftover, type(leftover))
